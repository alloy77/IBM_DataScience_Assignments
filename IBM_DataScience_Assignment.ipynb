# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we will summarize key concepts, languages, libraries, and tools used in Data Science.
# We will also perform some basic arithmetic operations using Python code.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science Libraries
# Commonly used libraries in Data Science include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow
# 6. Keras

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools | Category          |
# |---------------------|------------------|
# | Jupyter Notebook    | Development Tool |
# | RStudio             | IDE              |
# | Apache Spark        | Big Data Tool    |
# | TensorFlow          | Machine Learning |
# | Power BI            | Visualization    |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are a few examples of simple arithmetic operations such as addition and multiplication.

# %%
# This is a simple arithmetic expression to multiply and add numbers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# - List popular languages used in Data Science
# - List commonly used libraries by Data Scientists
# - Introduce Data Science tools
# - Demonstrate simple arithmetic operations using Python
# - Convert minutes to hours using Python code

# %% [markdown]
# ## Author
# **Ayushman Panigrahi**
